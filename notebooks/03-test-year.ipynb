# %%
import pandas as pd

# %%
chart_peek = pd.read_csv("../data/hot-100-2010.csv")

grouped = chart_peek.groupby(['date']).count().sort_values('date', ascending=False)

grouped
# Out:
#             title  artist  current  previous  peak  weeks
# date
# 2010-12-25    100     100      100       100   100    100
# 2010-12-18    100     100      100       100   100    100
# 2010-12-11    100     100      100       100   100    100
# 2010-12-04    100     100      100       100   100    100
# 2010-11-27    100     100      100       100   100    100
# 2010-11-20    100     100      100       100   100    100
# 2010-11-13    100     100      100       100   100    100
# 2010-11-06    100     100      100       100   100    100
# 2010-10-30    100     100      100       100   100    100
# 2010-10-23    100     100      100       100   100    100
# 2010-10-16    100     100      100       100   100    100
# 2010-10-09    100     100      100       100   100    100
# 2010-10-02    100     100      100       100   100    100
# 2010-09-25    100     100      100       100   100    100
# 2010-09-18    100     100      100       100   100    100
# 2010-09-11    100     100      100       100   100    100
# 2010-09-04    100     100      100       100   100    100
# 2010-08-28    100     100      100       100   100    100
# 2010-08-21    100     100      100       100   100    100
# 2010-08-14    100     100      100       100   100    100
# 2010-08-07    100     100      100       100   100    100
# 2010-07-31    100     100      100       100   100    100
# 2010-07-24    100     100      100       100   100    100
# 2010-07-17    100     100      100       100   100    100
# 2010-07-10    100     100      100       100   100    100
# 2010-07-03    100     100      100       100   100    100
# 2010-06-26    100     100      100       100   100    100
# 2010-06-19    100     100      100       100   100    100
# 2010-06-12    100     100      100       100   100    100
# 2010-06-05    100     100      100       100   100    100
# 2010-05-29    100     100      100       100   100    100
# 2010-05-22    100     100      100       100   100    100
# 2010-05-15    100     100      100       100   100    100
# 2010-05-08    100     100      100       100   100    100
# 2010-05-01    100     100      100       100   100    100
# 2010-04-24    100     100      100       100   100    100
# 2010-04-17    100     100      100       100   100    100
# 2010-04-10    100     100      100       100   100    100
# 2010-04-03    100     100      100       100   100    100
# 2010-03-27    100     100      100       100   100    100
# 2010-03-20    100     100      100       100   100    100
# 2010-03-13    100     100      100       100   100    100
# 2010-03-06    100     100      100       100   100    100
# 2010-02-27    100     100      100       100   100    100
# 2010-02-20    100     100      100       100   100    100
# 2010-02-13    100     100      100       100   100    100
# 2010-02-06    100     100      100       100   100    100
# 2010-01-30    100     100      100       100   100    100
# 2010-01-23    100     100      100       100   100    100
# 2010-01-16    100     100      100       100   100    100
# 2010-01-09    100     100      100       100   100    100
# 2010-01-02    100     100      100       100   100    100

# %%
len(chart_peek)
# Out:
# 5200
