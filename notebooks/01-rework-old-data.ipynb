# %% [markdown]
# # Rework of existing data
#
# Started to do this, then decided that pandas is stupid.

# %%
import pandas as pd

# %%
billboard = pd.read_csv("../data/billboard.csv")

# %%
billboard.columns
# Out:
# Index(['url', 'WeekID', 'Week Position', 'Song', 'Performer', 'SongID',
#        'Instance', 'Previous Week Position', 'Peak Position',
#        'Weeks on Chart'],
#       dtype='object')

# %%
billboard[[
    'WeekID',
    'Song',
    'Performer',
    'Week Position',
    'Previous Week Position',
    'Peak Position',
    'Weeks on Chart'
]].sort_values(by="WeekID")
# Out:
#           WeekID                                      Song  \
# 36234   1/1/1966                           I See The Light
# 224592  1/1/1966            Uptight (Everything's Alright)
# 177869  1/1/1966  One Has My Name (The Other Has My Heart)
# 67205   1/1/1966                       Flowers On The Wall
# 81880   1/1/1966                        Jenny Take A Ride!
# ...          ...                                       ...
# 246610  9/9/2017                             XO TOUR Llif3
# 256155  9/9/2017                         Whatever You Need
# 61001   9/9/2017                          Butterfly Effect
# 130306  9/9/2017                               No Promises
# 133502  9/9/2017                          Drinkin' Problem
#
#                                               Performer  Week Position  \
# 36234                                The Five Americans             92
# 224592                                    Stevie Wonder             78
# ...
